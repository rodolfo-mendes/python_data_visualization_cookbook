# %%
# import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.figure()
plt.plot([1,2,3,2,3,2,2,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot([4,3,2,1], [1,2,3,4])

# %%
# sample data
x = [1,2,3,4]
y = [5,4,3,2]

# %%
plt.figure('Sample Charts')
plt.subplot(2, 3, 1) # divide subplots into a 2x3 grid and select cell #1
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(2, 3, 2) # select cell #2
plt.bar(x, y) #plot a vertical bar chart
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(2, 3, 3) # select cell #3
plt.barh(x, y) #plot a horizontal bar chart
# Out:
# <BarContainer object of 4 artists>

# %%
# create stacked bar chart
plt.subplot(2, 3, 4)
plt.bar(x, y)

y1 = [7, 8, 5, 3]
plt.bar(x, y1, bottom=y)
# Out:
# <BarContainer object of 4 artists>

# %%
# boxplot
plt.subplot(2, 3, 5)
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xa58fb70>,
#   <matplotlib.lines.Line2D at 0xa599048>],
#  'caps': [<matplotlib.lines.Line2D at 0xa599470>,
#   <matplotlib.lines.Line2D at 0xa599898>],
#  'boxes': [<matplotlib.lines.Line2D at 0xa58fa20>],
#  'medians': [<matplotlib.lines.Line2D at 0xa599cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xa5a2128>],
#  'means': []}

# %%
# scatter plot
plt.subplot(2, 3, 6, )
plt.scatter(x, y)
