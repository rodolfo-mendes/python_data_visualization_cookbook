# %%
# import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.figure()
plt.plot([1,2,3,2,3,2,2,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot([4,3,2,1], [1,2,3,4])

# %%
# sample data
x = [1,2,3,4]
y = [5,4,3,2]

# %%
plt.figure('Sample Charts')
plt.subplot(2, 3, 1) # divide subplots into a 2x3 grid and select cell #1
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(2, 3, 2) # select cell #2
plt.bar(x, y) #plot a vertical bar chart
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(2, 3, 3) # select cell #3
plt.barh(x, y) #plot a horizontal bar chart
# Out:
# <BarContainer object of 4 artists>

# %%
# create stacked bar chart
plt.subplot(2, 3, 4)
plt.bar(x, y)

y1 = [7, 8, 5, 3]
plt.bar(x, y1, bottom=y)
# Out:
# <BarContainer object of 4 artists>

# %%
# boxplot
plt.subplot(2, 3, 5)
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f919e5da2e8>,
#   <matplotlib.lines.Line2D at 0x7f919e43e208>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f919e43e630>,
#   <matplotlib.lines.Line2D at 0x7f919e43ea58>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f919e433c18>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f919e43ee80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f919e4452e8>],
#  'means': []}

# %%
# scatter plot
plt.subplot(2, 3, 6, )
plt.scatter(x, y)

# %%
plt.figure(1)
plt.scatter(x,y)

# %%
plt.figure(2)
plt.scatter(y,x)

# %%
z = range(1,20)
plt.figure()
plt.boxplot(z)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f919e338e80>,
#   <matplotlib.lines.Line2D at 0x7f919e342358>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f919e342780>,
#   <matplotlib.lines.Line2D at 0x7f919e342ba8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f919e338d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f919e342fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f919e34b438>],
#  'means': []}

# %%
import pylab as pl

dataset = ([113, 115, 119, 121, 124,
            124, 125, 126, 126, 126,
            127, 127, 128, 129, 130, 
            130, 131, 132, 133, 136])

plt.figure()
plt.subplot(1, 2, 1)
plt.boxplot(dataset, vert=False)

plt.subplot(1, 2, 2)
plt.hist(dataset)
# Out:
# <img src="data:image/png;base64,..." width="896">
# (array([2., 0., 1., 1., 2., 4., 4., 3., 2., 1.]),
#  array([113. , 115.3, 117.6, 119.9, 122.2, 124.5, 126.8, 129.1, 131.4,
#         133.7, 136. ]),
#  <a list of 10 Patch objects>)
