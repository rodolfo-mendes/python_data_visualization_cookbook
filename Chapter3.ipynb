# %%
# import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
plt.figure()
_ = plt.plot([1,2,3,2,3,2,2,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_ = plt.plot([4,3,2,1], [1,2,3,4])

# %%
# sample data
x = [1,2,3,4]
y = [5,4,3,2]

# %%
plt.figure('Sample Charts')
plt.subplot(2, 3, 1) # divide subplots into a 2x3 grid and select cell #1
_ = plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(2, 3, 2) # select cell #2
_ = plt.bar(x, y) #plot a vertical bar chart

# %%
plt.subplot(2, 3, 3) # select cell #3
_ = plt.barh(x, y) #plot a horizontal bar chart

# %%
# create stacked bar chart
plt.subplot(2, 3, 4)
plt.bar(x, y)

y1 = [7, 8, 5, 3]
_ = plt.bar(x, y1, bottom=y)

# %%
# boxplot
plt.subplot(2, 3, 5)
_ = plt.boxplot(x)

# %%
# scatter plot
plt.subplot(2, 3, 6, )
_ = plt.scatter(x, y)

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
y = np.cos(x)
y1 = np.sin(x)

plt.figure()
plt.plot(x, y)
plt.plot(x, y1)

plt.title(r'Functions $\sin$ and $\cos$')
plt.xlim(-3.0, 3.0)
plt.ylim(-1.0, 1.0)

(plt.xticks(
    [-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
    [r'$-\pi$', r'$-\frac{\pi}{2}$', r'$0$', r'$\frac{\pi}{2}$', r'$\pi$']))

plt.yticks([-1, 0, 1], [r'$-1$',r'$0$',r'$+1$'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(1)
_ = plt.scatter(x,y)

# %%
plt.figure(2)
_ = plt.scatter(y,x)

# %%
z = range(1,20)
plt.figure()
_ = plt.boxplot(z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pylab as pl

dataset = ([113, 115, 119, 121, 124,
            124, 125, 126, 126, 126,
            127, 127, 128, 129, 130, 
            130, 131, 132, 133, 136])

plt.figure()
plt.subplot(1, 2, 1)
plt.boxplot(dataset, vert=False)

plt.subplot(1, 2, 2)
_ = plt.hist(dataset)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.axis()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.axis([-1.0, 1.0, -10.0, 10]) # xmin, xmax, ymin, ymax
# Out:
# [-1.0, 1.0, -10.0, 10]

# %%
_ = plt.axhline()

# %%
_ = plt.axvline()

# %%
_ = plt.axhline(4)

# %%
_ = plt.axhspan(-1, 1, color='tab:orange', alpha=0.4)

# %%
_ = plt.axes((0.65, 0.65, 0.2, 0.2))

# %%
x = np.arange(0, 1, step=0.1)
y = x ** 2
_ = plt.scatter(x, y)

# %%
plt.grid(which='minor')

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
y = np.cos(x)
y1 = np.sin(x)

# %%
plt.figure()
_ = plt.plot(x, y, linewidth=10) #setting line property at plot time
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
line, = plt.plot(x, y1) #saving a reference for later manipulation

# %%
line.set_linewidth(5) #setting linewidth property on line object

# %%
_ = plt.setp(line, 'linewidth', 3) # MATLAB style

# %%
_ = plt.setp(line, linewidth = 4)

# %%
line.set_ydata(x ** 2)

# %%
# list colors supported by matplotlib
plt.colors() # deprecated
# Out:
# /opt/rodolfo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: The colors function was deprecated in version 2.1.

# %%
# testing for different line styles, colors and markers

x = np.arange(0, 10)

plt.figure()
l1 = plt.plot(x, 0.1 * x, color='yellowgreen', alpha=0.6, linestyle='-', marker='o')
l2 = plt.plot(x, 0.2 * x, color='maroon', alpha=0.6, linestyle='--', marker='D')
l3 = plt.plot(x, 0.3 * x, color='royalblue', alpha=0.6, linestyle='-.', marker='*', linewidth=3)
l4 = plt.plot(x, 0.5 * x, color='darkorange', alpha=0.6, linestyle=':', marker='v')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# testing different cap and join styles
x = np.arange(0, 10)
y = np.array( [0, 10, 20, 30, 25, 15, 8, 17, 31, 40] )

plt.figure()
l1, = plt.plot(x, y, linewidth = 7) #defaults: projecting and round
l2 = plt.plot(x, y + 10 , linewidth = 7, solid_capstyle='projecting', solid_joinstyle='round')
l3 = plt.plot(x, y + 20, linewidth = 7, solid_capstyle='round', solid_joinstyle='bevel')
l4 = plt.plot(x, y + 30, linewidth = 7, solid_capstyle='butt', solid_joinstyle='miter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
l1.get_solid_capstyle()
# Out:
# 'projecting'

# %%
l1.get_solid_joinstyle()
# Out:
# 'round'
