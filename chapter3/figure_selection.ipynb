# %%
# import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
plt.figure()
_ = plt.plot([1,2,3,2,3,2,2,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_ = plt.plot([4,3,2,1], [1,2,3,4])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.random.uniform(low=0, high=8, size=10)
y = np.random.uniform(low=1, high=3, size=10)

plt.figure(1)
_ = plt.scatter(x, y)

# %%
x = np.random.uniform(low=0, high=8, size=10)
y = np.random.uniform(low=1, high=3, size=10)

plt.figure(2)
_ = plt.scatter(x, y)
