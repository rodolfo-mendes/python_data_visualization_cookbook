# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
mu = 100
sigma = 15
x = np.random.normal(mu, sigma, 1000)

# %%
ax = plt.gca()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_ = ax.hist(x, bins=35, color='tab:red', alpha=0.3)

# %%
ax.set_xlabel('Values')
ax.set_ylabel('Frequency')
# Out:
# Text(56.4167,0.5,'Frequency')

# %%
_ = ax.set_title(r'$\mathrm{Histogram:}\ \mu=%d,\ \sigma=%d $' % (mu, sigma))

# %% [markdown]
# ### The same data, displayed in horizontal

# %%
plt.figure()
_ = plt.hist(x, bins=35, color='tab:red', alpha=0.3, orientation='horizontal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Other types of histogram

# %%
plt.figure()
_ = plt.hist(x, bins=35, color='tab:red', alpha=0.3, histtype='step')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_ = plt.hist(x, bins=35, color='tab:red', alpha=0.3, histtype='stepfilled')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Stacked bar

# %%
# more data
x1 = np.random.normal(mu, sigma, 1000)

# %%
plt.figure()
plt.hist([x, x1], bins=35, stacked=True)
#plt.hist(x1, bins=35, stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([array([  1.,   1.,   2.,   6.,   7.,  10.,  18.,  14.,  35.,  45.,  47.,
#           73.,  69.,  80., 100.,  78.,  84.,  62.,  73.,  55.,  53.,  35.,
#           20.,  13.,   5.,   5.,   3.,   2.,   1.,   2.,   0.,   0.,   0.,
#            0.,   1.]),
#   array([  5.,   1.,   4.,  11.,  11.,  24.,  33.,  33.,  69.,  89.,  93.,
#          139., 140., 154., 197., 158., 159., 134., 152., 118.,  92.,  63.,
#           46.,  31.,  15.,   8.,   9.,   5.,   4.,   2.,   0.,   0.,   0.,
#            0.,   1.])],
#  array([ 51.34104048,  54.59547454,  57.84990861,  61.10434268,
#          64.35877675,  67.61321082,  70.86764489,  74.12207896,
#          77.37651303,  80.6309471 ,  83.88538117,  87.13981524,
#          90.39424931,  93.64868338,  96.90311745, 100.15755152,
#         103.41198559, 106.66641966, 109.92085373, 113.1752878 ,
#         116.42972187, 119.68415594, 122.93859001, 126.19302408,
# ...
